# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import urllib.request
import json

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import style 
plt.style.use(['dark_background'])
import seaborn as sns 
sns.set(color_codes = True)
style.use('seaborn-ticks')
sns.set(color_codes = True)

# %% [markdown]
# # Universities in Poland,Germany etc

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#                         UNIVERSITY NAME  ...                                            WEBSITE
# 0           University of Bozen-Bolzano  ...  https://www.unibz.it/en/faculties/computer-sci...
# 1           University of Bozen-Bolzano  ...  https://www.unibz.it/en/faculties/computer-sci...
# 2  Università Cattolica del Sacro Cuore  ...  https://offertaformativa.unicatt.it/cdl-data-a...
# 3      Ca' Foscari University of Venice  ...  https://www.studyatcafoscari.com/programmes/gr...
# 4                   University of Siena  ...  https://www.unisi-international.com/programmes...
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UNIVERSITY NAME          138 non-null    object
#  1   NAME OF MASTER PROGRAM   138 non-null    object
#  2   COUNTRY                  138 non-null    object
#  3   CITY                     138 non-null    object
#  4   LANG.                    138 non-null    object
#  5   SEMESTER                 138 non-null    float64
#  6   Tuition fee(€)/SEMESTER  120 non-null    float64
#  7   APPLY                    125 non-null    object
#  8   START                    81 non-null     object
#  9   REQUIREMENT              131 non-null    object
#  10  WEBSITE                  117 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 13.0+ KB

# %%
df.rename(columns = {"UNIVERSITY NAME":"UNIVERSITY_NAME"},inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UNIVERSITY_NAME          138 non-null    object
#  1   NAME OF MASTER PROGRAM   138 non-null    object
#  2   COUNTRY                  138 non-null    object
#  3   CITY                     138 non-null    object
#  4   LANG.                    138 non-null    object
#  5   SEMESTER                 138 non-null    float64
#  6   Tuition fee(€)/SEMESTER  120 non-null    float64
#  7   APPLY                    125 non-null    object
#  8   START                    81 non-null     object
#  9   REQUIREMENT              131 non-null    object
#  10  WEBSITE                  117 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 13.0+ KB

# %%
df.rename(columns = {"NAME OF MASTER PROGRAM":"NAME_OF_MASTER_PROGRAM"},inplace = True)
df.rename(columns = {"Tuition fee(€)/SEMESTER":"TUITION_FEE_PER_SEM"},inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   UNIVERSITY_NAME         138 non-null    object
#  1   NAME_OF_MASTER_PROGRAM  138 non-null    object
#  2   COUNTRY                 138 non-null    object
#  3   CITY                    138 non-null    object
#  4   LANG.                   138 non-null    object
#  5   SEMESTER                138 non-null    float64
#  6   TUITION_FEE_PER_SEM     120 non-null    float64
#  7   APPLY                   125 non-null    object
#  8   START                   81 non-null     object
#  9   REQUIREMENT             131 non-null    object
#  10  WEBSITE                 117 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 13.0+ KB

# %%
df.UNIVERSITY_NAME.isnull().count()
# Out:
# 150

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   UNIVERSITY_NAME         138 non-null    object
#  1   NAME_OF_MASTER_PROGRAM  138 non-null    object
#  2   COUNTRY                 138 non-null    object
#  3   CITY                    138 non-null    object
#  4   LANG.                   138 non-null    object
#  5   SEMESTER                138 non-null    float64
#  6   TUITION_FEE_PER_SEM     120 non-null    float64
#  7   APPLY                   125 non-null    object
#  8   START                   81 non-null     object
#  9   REQUIREMENT             131 non-null    object
#  10  WEBSITE                 117 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 13.0+ KB

# %%
copy = df.copy()

# %%
for i,r in copy.iterrows():    #Iterating row wise
            if pd.isnull(r).any():    #Gives true if any of them is true.
               copy.drop(i,inplace = True)

# %%
copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 0 to 134
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   UNIVERSITY_NAME         47 non-null     object
#  1   NAME_OF_MASTER_PROGRAM  47 non-null     object
#  2   COUNTRY                 47 non-null     object
#  3   CITY                    47 non-null     object
#  4   LANG.                   47 non-null     object
#  5   SEMESTER                47 non-null     float64
#  6   TUITION_FEE_PER_SEM     47 non-null     float64
#  7   APPLY                   47 non-null     object
#  8   START                   47 non-null     object
#  9   REQUIREMENT             47 non-null     object
#  10  WEBSITE                 47 non-null     object
# dtypes: float64(2), object(9)
# memory usage: 4.4+ KB

# %%
copy.head()
# Out:
#                     UNIVERSITY_NAME  ...                                            WEBSITE
# 0       University of Bozen-Bolzano  ...  https://www.unibz.it/en/faculties/computer-sci...
# 1       University of Bozen-Bolzano  ...  https://www.unibz.it/en/faculties/computer-sci...
# 3  Ca' Foscari University of Venice  ...  https://www.studyatcafoscari.com/programmes/gr...
# 5              University of Verona  ...  https://www.corsi.univr.it/?ent=cs&id=955&lang=en
# 6                University of Pisa  ...  https://didattica.di.unipi.it/laurea-magistral...
#
# [5 rows x 11 columns]

# %%
copy[['NAME_OF_MASTER_PROGRAM','UNIVERSITY_NAME','COUNTRY','TUITION_FEE_PER_SEM']].groupby(['COUNTRY']).mean()*88.40
# In INDIAN RUPEES
# Out:
#           TUITION_FEE_PER_SEM
# COUNTRY
# Germany         109896.800000
# Italy            44077.600000
# Poland          156615.333333
# Portugal        134810.000000

# %% [markdown]
# Total Universities in Data in each country

# %%
df[['UNIVERSITY_NAME','COUNTRY']].groupby(['COUNTRY']).count()
# Out:
#           UNIVERSITY_NAME
# COUNTRY
# Austria                 7
# Belgium                 4
# Germany                75
# Italy                  20
# Norway                  6
# Poland                 21
# Portugal                5

# %%
df[['UNIVERSITY_NAME','COUNTRY','CITY']].groupby(['COUNTRY','CITY']).count()
# Out:
#                      UNIVERSITY_NAME
# COUNTRY  CITY
# Austria  Graz                      1
#          Innsbruck                 2
#          Klagenfurt                1
#          Linz                      2
#          Vienna                    1
# ...                              ...
# Poland   Lodz                      1
#          Lublin                    1
#          Warsaw                    9
#          Wroclaw                   6
# Portugal Lisbon                    5
#
# [81 rows x 1 columns]

# %% [markdown]
# Out of the above universities university with all data given

# %%
copy[['UNIVERSITY_NAME','COUNTRY']].groupby(['COUNTRY']).count()
# Out:
#           UNIVERSITY_NAME
# COUNTRY
# Germany                17
# Italy                  13
# Poland                 15
# Portugal                2

# %%
df.sort_values()

# %%
copy[['UNIVERSITY_NAME','COUNTRY','CITY']].groupby(['COUNTRY','CITY']).count()
# Out:
#                               UNIVERSITY_NAME
# COUNTRY  CITY
# Germany  Bamberg                            1
#          Berlin                             1
#          Bonn                               1
#          Düsseldorf                         1
#          Garching b. München                1
#          Heidelberg                         1
#          Hof                                2
#          Jena                               2
#          Konstanz                           1
#          Passau                             1
#          Saarbrücken                        1
#          Siegen                             1
#          Trier                              2
#          Wuppertal                          1
# Italy    Bozen                              3
#          Camerino                           1
#          Pisa                               4
#          Rome                               1
#          Trento                             1
# ...

# %%
copy['UNIVERSITY_NAME'].unique()
# Out:
# array(['University of Bozen-Bolzano', "Ca' Foscari University of Venice",
#        'University of Verona', 'University of Pisa',
#        'University of Trento', 'University of Camerino',
#        'Sapienza University of Rome', 'University of Wuppertal ',
#        'Technische Universität München',
#        'Hof University of Applied Sciences', 'Saarland University',
#        'Trier University', 'University of Passau',
#        'University of Konstanz', 'SRH University Heidelberg ',
#        'University of Siegen', 'Friedrich Schiller University Jena',
#        'University of Bamberg', 'Hertie School',
#        'Heinrich Heine University Düsseldorf', 'University of Bonn',
#        'Warsaw University of Technology',
#        'Wroclaw University of Science and Technology',
#        'Silesian University of Technology',
#        'Lublin University of Technology',
#        'Warsaw School of Computer Science', 'University of Warsaw',
# ...

# %%
copy['LANG.'].unique()
# Out:
# array(['English'], dtype=object)

# %%
copy['REQUIREMENT'].unique()
# Out:
# array(['ENG-C1', 'ENG-B2', '7/10 NOT ORT', 'IELTS6 veya87',
#        'IELTS 6 TOEFL 79 VEYA B2 NOTORT3', 'IELTS 6.5 TOEFL88',
#        'IELTS 6.5 TOEFL90 A1CEFR-GERMAN', 'IELTS 6.5 TOEFL 95 ',
#        'IELTS 6 TOEFL80 NOTORT2 ', 'IELTS 6 TOEFL 80',
#        'IELTS 6.5 TOEFL 90 C1-GER', 'IELTS 5.5 TOEFL 87 GER-A1',
#        'IELTS 6.5 TOEFL 80', 'IELTS 6.5 TOEFL 94', 'IELTS 6.5 TOEFL 90',
#        'IELTS 7 TOEFL 100', 'IELTS 6 TOEFL 87 CEFRB2', 'IELTS 6 TOEFL 90',
#        'IELTS 6 TOEFL 87', 'IELTS 6.5 TOEFL 87', 'IELTS 5.5 TOEFL 72',
#        'IELTS 5.5 TOEFL 87'], dtype=object)

# %%
copy[['UNIVERSITY_NAME','REQUIREMENT','COUNTRY']].groupby(['COUNTRY','REQUIREMENT']).count()
# Out:
#                                            UNIVERSITY_NAME
# COUNTRY  REQUIREMENT
# Germany  ENG-B2                                          2
#          IELTS 5.5 TOEFL 87 GER-A1                       1
#          IELTS 6 TOEFL 79 VEYA B2 NOTORT3                1
#          IELTS 6 TOEFL 80                                2
#          IELTS 6 TOEFL 87 CEFRB2                         1
#          IELTS 6 TOEFL 90                                1
#          IELTS 6 TOEFL80 NOTORT2                         1
#          IELTS 6.5 TOEFL 80                              1
#          IELTS 6.5 TOEFL 90                              1
#          IELTS 6.5 TOEFL 90 C1-GER                       1
#          IELTS 6.5 TOEFL 94                              1
#          IELTS 6.5 TOEFL 95                              1
#          IELTS 6.5 TOEFL88                               1
#          IELTS 6.5 TOEFL90 A1CEFR-GERMAN                 1
#          IELTS 7 TOEFL 100                               1
# ...

# %% [markdown]
# Which college takes lowest tutition fee?? in EURO

# %%
copy[['UNIVERSITY_NAME','TUITION_FEE_PER_SEM','NAME_OF_MASTER_PROGRAM','COUNTRY','REQUIREMENT','SEMESTER','APPLY','START']].groupby('COUNTRY').min()
# Out:
#                              UNIVERSITY_NAME  ...     START
# COUNTRY                                       ...
# Germany   Friedrich Schiller University Jena  ...  01/01/21
# Italy       Ca' Foscari University of Venice  ...  01/09/22
# Poland       Lublin University of Technology  ...  01/02/22
# Portugal                            NOVA IMS  ...  01/09/22
#
# [4 rows x 7 columns]

# %% [markdown]
# Which college takes highest tutition fee?? in EURO

# %%
copy[['UNIVERSITY_NAME','TUITION_FEE_PER_SEM','NAME_OF_MASTER_PROGRAM','COUNTRY','REQUIREMENT','SEMESTER','APPLY','START']].groupby('COUNTRY').max()
# Out:
#                                        UNIVERSITY_NAME  ...     START
# COUNTRY                                                 ...
# Germany                       University of Wuppertal   ...  30/11/21
# Italy                             University of Verona  ...  01/10/22
# Poland    Wroclaw University of Science and Technology  ...  01/10/22
# Portugal                                      NOVA IMS  ...  01/09/22
#
# [4 rows x 7 columns]

# %% [markdown]
# TUTITON FEE VARIATION

# %%
copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 0 to 134
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   UNIVERSITY_NAME         47 non-null     object
#  1   NAME_OF_MASTER_PROGRAM  47 non-null     object
#  2   COUNTRY                 47 non-null     object
#  3   CITY                    47 non-null     object
#  4   LANG.                   47 non-null     object
#  5   SEMESTER                47 non-null     float64
#  6   TUITION_FEE_PER_SEM     47 non-null     float64
#  7   APPLY                   47 non-null     object
#  8   START                   47 non-null     object
#  9   REQUIREMENT             47 non-null     object
#  10  WEBSITE                 47 non-null     object
# dtypes: float64(2), object(9)
# memory usage: 5.7+ KB

# %%
sns.kdeplot(df.TUITION_FEE_PER_SEM)

# %% [markdown]
# Number of institutions:

# %%
c = df.groupby('COUNTRY')['COUNTRY'].count()
sns.barplot(x = c.index,y=c.values)

# %%
c = copy.groupby('COUNTRY')['COUNTRY'].count()
sns.barplot(x = c.index,y=c.values)

# %%
plt.xticks(rotation=90);  
c = df.groupby('CITY')['CITY'].count()
sns.barplot(x = c.index,y=c.values)

# %%
sns.pairplot(df)

# %% [markdown]
# # Universities in US

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import style 
plt.style.use(['dark_background'])
import seaborn as sns 
sns.set(color_codes = True)
style.use('seaborn-ticks')
sns.set(color_codes = True)

# %%
df = pd.read_csv('cau.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7735 entries, 0 to 7734
# Data columns (total 46 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           7735 non-null   float64
#  1   Y           7735 non-null   float64
#  2   FID         7735 non-null   int64
#  3   IPEDSID     7735 non-null   int64
#  4   NAME        7735 non-null   object
#  5   ADDRESS     7735 non-null   object
#  6   ADDRESS2    7735 non-null   object
#  7   CITY        7735 non-null   object
#  8   STATE       7735 non-null   object
#  9   ZIP         7735 non-null   object
#  10  ZIP4        7735 non-null   object
#  11  TELEPHONE   7735 non-null   object
#  12  TYPE        7735 non-null   int64
#  13  STATUS      7735 non-null   object
#  14  POPULATION  7735 non-null   int64
#  15  COUNTY      7735 non-null   object
#  16  COUNTYFIPS  7735 non-null   int64
#  17  COUNTRY     7735 non-null   object
#  18  LATITUDE    7735 non-null   float64
# ...

# %%
df.head()
# Out:
#             X          Y   FID  ...  DORM_CAP TOT_EMPLOY     SHELTER_ID
# 0  -92.260490  34.759308  7001  ...         0         18  NOT AVAILABLE
# 1 -121.289431  38.713353  7002  ...         0          9  NOT AVAILABLE
# 2 -118.287070  34.101481  7003  ...         0         11  NOT AVAILABLE
# 3 -121.652662  36.700631  7004  ...         0          9  NOT AVAILABLE
# 4  -71.070737  42.369930  7005  ...         0        143  NOT AVAILABLE
#
# [5 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7735 entries, 0 to 7734
# Data columns (total 46 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           7735 non-null   float64
#  1   Y           7735 non-null   float64
#  2   FID         7735 non-null   int64
#  3   IPEDSID     7735 non-null   int64
#  4   NAME        7735 non-null   object
#  5   ADDRESS     7735 non-null   object
#  6   ADDRESS2    7735 non-null   object
#  7   CITY        7735 non-null   object
#  8   STATE       7735 non-null   object
#  9   ZIP         7735 non-null   object
#  10  ZIP4        7735 non-null   object
#  11  TELEPHONE   7735 non-null   object
#  12  TYPE        7735 non-null   int64
#  13  STATUS      7735 non-null   object
#  14  POPULATION  7735 non-null   int64
#  15  COUNTY      7735 non-null   object
#  16  COUNTYFIPS  7735 non-null   int64
#  17  COUNTRY     7735 non-null   object
#  18  LATITUDE    7735 non-null   float64
# ...

# %%
df_small = df[['CITY','COUNTY','STATE','TYPE','STATUS','VAL_METHOD','NAME','NAICS_DESC','TOT_ENROLL','TOT_EMPLOY','POPULATION']]

# %%
df_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7735 entries, 0 to 7734
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CITY        7735 non-null   object
#  1   COUNTY      7735 non-null   object
#  2   STATE       7735 non-null   object
#  3   TYPE        7735 non-null   int64
#  4   STATUS      7735 non-null   object
#  5   VAL_METHOD  7735 non-null   object
#  6   NAME        7735 non-null   object
#  7   NAICS_DESC  7735 non-null   object
#  8   TOT_ENROLL  7735 non-null   int64
#  9   TOT_EMPLOY  7735 non-null   int64
#  10  POPULATION  7735 non-null   int64
# dtypes: int64(4), object(7)
# memory usage: 664.9+ KB

# %%
df[['CITY','COUNTY','STATE','TYPE','STATUS','VAL_METHOD','NAME','NAICS_DESC','TOT_ENROLL','TOT_EMPLOY','POPULATION']].groupby(['COUNTY','STATE','TYPE','NAME']).count()
# Out:
#                                                                      CITY  ...  POPULATION
# COUNTY    STATE TYPE NAME                                                  ...
# Abbeville SC    2    Erskine College                                    1  ...           1
# Acadia    LA    1    Louisiana State University Eunice                  1  ...           1
# Accomack  VA    1    Eastern Shore Community College                    1  ...           1
# Ada       ID    1    Boise State University                             1  ...           1
#                 2    Boise Bible College                                1  ...           1
# ...                                                                   ...  ...         ...
# York      SC    2    Clinton Junior College                             1  ...           1
#                 3    Kenneth Shuler School of Cosmetology-Rock Hill     1  ...           1
# ...

# %%
df[['VAL_METHOD','NAME']].groupby(['VAL_METHOD']).count()
# Out:
#                NAME
# VAL_METHOD
# Geocode        1387
# Imagery        2736
# Imagery/Other  3483
# UnVerified      129

# %%
df[['TYPE','NAME']].groupby(['TYPE']).count()
# Out:
#       NAME
# TYPE
# -3       1
#  1    2110
#  2    1954
#  3    3670

# %%
df[['NAICS_DESC','NAME']].groupby(['NAICS_DESC']).count()
# Out:
#                                                   NAME
# NAICS_DESC
# Business and Secretarial Schools                    60
# Colleges, Universities, and Professional Schools  2893
# Computer Training                                   45
# Cosmetology and Barber Schools                    1374
# Educational Support Services/Closed                139
# Fine Arts Schools                                   45
# Flight Training                                     14
# Junior Colleges                                   2027
# Other Technical and Trade Schools                 1138

# %%
df[['STATUS','NAME']].groupby(['STATUS']).count()
# Out:
#         NAME
# STATUS
# A       7438
# C         18
# D         32
# M         37
# N        195
# R         15

# %%
df[['CITY','NAME']].groupby(['CITY']).count()
# Out:
#               NAME
# CITY
# ARTESIA          1
# Aberdeen         3
# Abilene          5
# Abingdon         2
# Abington         1
# ...            ...
# Yucaipa          1
# Yucca Valley     1
# Yukon            1
# Yuma             1
# Zanesville       4
#
# [2529 rows x 1 columns]

# %% [markdown]
# #STUDENT PERFORMANCE

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import style 
plt.style.use(['dark_background'])
import seaborn as sns 
sns.set(color_codes = True)
style.use('seaborn-ticks')
sns.set(color_codes = True)

# %%
df = pd.read_csv("sp.csv")
df.head(3)
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
#
# [3 rows x 8 columns]

# %%
df[['gender','race/ethnicity']].groupby('gender').count()
# Out:
#         race/ethnicity
# gender
# female             518
# male               482

# %%
df[['gender','race/ethnicity']].groupby('race/ethnicity').count()
# Out:
#                 gender
# race/ethnicity
# group A             89
# group B            190
# group C            319
# group D            262
# group E            140

# %%
df[['gender','math score','reading score','writing score','parental level of education']].groupby(['parental level of education','gender']).mean()
# Out:
#                                     math score  reading score  writing score
# parental level of education gender
# associate's degree          female   65.250000      74.120690      74.000000
#                             male     70.764151      67.433962      65.405660
# bachelor's degree           female   68.349206      77.285714      78.380952
#                             male     70.581818      68.090909      67.654545
# high school                 female   59.351064      68.202128      66.691489
#                             male     64.705882      61.480392      58.539216
# master's degree             female   66.500000      76.805556      77.638889
#                             male     74.826087      73.130435      72.608696
# some college                female   65.406780      73.550847      74.050847
#                             male     69.009259      64.990741      63.148148
# some high school            female   59.296703      69.109890      68.285714
# ...

# %%
# MALE PERFORMED WELL IN ONLY MATH IN ALL DEGREED

# %%
df['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
df[['gender','math score','reading score','writing score','parental level of education','lunch']].groupby(['lunch','parental level of education','gender']).mean()
# Out:
#                                                  math score  ...  writing score
# lunch        parental level of education gender              ...
# free/reduced associate's degree          female   57.972222  ...      69.500000
#                                          male     66.682927  ...      62.975610
#              bachelor's degree           female   63.363636  ...      75.818182
#                                          male     62.636364  ...      62.636364
#              high school                 female   51.621622  ...      60.567568
#                                          male     57.757576  ...      53.848485
#              master's degree             female   57.785714  ...      72.000000
#                                          male     65.900000  ...      66.900000
#              some college                female   58.454545  ...      68.522727
#                                          male     62.228571  ...      57.657143
# ...

# %%
df[['gender','math score','reading score','writing score','parental level of education','lunch']].groupby(['lunch','gender']).mean()
# Out:
#                      math score  reading score  writing score
# lunch        gender
# free/reduced female   55.814815      67.386243      66.444444
#              male     62.457831      61.542169      59.126506
# standard     female   68.124620      75.607903      75.927052
#              male     72.022152      67.537975      65.509494

# %%
df.head(3)
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
#
# [3 rows x 8 columns]

# %%
df['average'] = (df['math score'] + df['reading score']+df['writing score'])/300

# %%
df[['gender','average']].groupby(['gender']).mean()*100
#ON AVERAGE FEMALES PERFORMED BETTER
# Out:
#           average
# gender
# female  69.569498
# male    65.837483

# %%
df[['gender','average','race/ethnicity']].groupby(['race/ethnicity']).mean()*100
# A<B<C<D<E
# Out:
#                   average
# race/ethnicity
# group A         62.992509
# group B         65.468421
# group C         67.131661
# group D         69.179389
# group E         72.752381

# %%
df[['gender','average','race/ethnicity']].groupby(['race/ethnicity','gender']).mean()*100
#THERE IS SOME PARIALITY AMONG TEACHING OR THE SPLITTING OF GROUPS
# a<b<c<d<e
# Out:
#                          average
# race/ethnicity gender
# group A        female  65.129630
#                male    61.540881
# group B        female  67.509615
#                male    63.000000
# group C        female  68.585185
#                male    65.249400
# group D        female  71.439276
#                male    66.987469
# group E        female  74.062802
#                male    71.478873

# %%
df[['gender','average','race/ethnicity','lunch']].groupby(['lunch','race/ethnicity','gender']).mean()*100
# Out:
#                                       average
# lunch        race/ethnicity gender
# free/reduced group A        female  56.428571
#                             male    58.439394
#              group B        female  64.299145
#                             male    56.655556
#              group C        female  60.827957
#                             male    59.916667
#              group D        female  66.019608
#                             male    63.098485
#              group E        female  65.724638
#                             male    69.759259
# standard     group A        female  70.666667
#                             male    63.741935
#              group B        female  69.435897
#                             male    66.398810
#              group C        female  72.661017
#                             male    68.436782
#              group D        female  74.982906
#                             male    68.910112
#              group E        female  78.231884
# ...

# %%
df[['gender','average','race/ethnicity','lunch']].groupby(['lunch','race/ethnicity']).mean()*100
# A<C<B<D<E
#A<B<C<D<E
# Out:
#                                average
# lunch        race/ethnicity
# free/reduced group A         57.657407
#              group B         60.975845
#              group C         60.412281
#              group D         64.666667
#              group E         67.495935
# standard     group A         66.616352
#              group B         68.030303
#              group C         70.868293
#              group D         71.746507
#              group E         74.929293

# %% [markdown]
# IN OVERALL PERFORMANCE Standard performs(69.1) more better than free(61.6)

# %%
df[['gender','average','race/ethnicity','lunch']].groupby(['lunch','gender','race/ethnicity']).mean()*100
# Out:
#                                       average
# lunch        gender race/ethnicity
# free/reduced female group A         56.428571
#                     group B         64.299145
#                     group C         60.827957
#                     group D         66.019608
#                     group E         65.724638
#              male   group A         58.439394
#                     group B         56.655556
#                     group C         59.916667
#                     group D         63.098485
#                     group E         69.759259
# standard     female group A         70.666667
#                     group B         69.435897
#                     group C         72.661017
#                     group D         74.982906
#                     group E         78.231884
#              male   group A         63.741935
#                     group B         66.398810
#                     group C         68.436782
#                     group D         68.910112
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   sum                          1000 non-null   float64
#  9   average                      1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB

# %%
df.drop('sum',axis = 1,inplace=True)

# %%
df.drop('average',axis = 1,inplace = True)

# %%
sns.pairplot(df,hue = 'gender')

# %%
df_1 = df.copy()
df_1 = df_1[ 
            (df_1['lunch']=='standard')
]
df_1.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 4    male        group C  ...            78            75
# 5  female        group B  ...            83            78
#
# [5 rows x 8 columns]

# %%
df_2 = df.copy()
df_2 = df_2[ 
            (df_2['lunch']=='free/reduced')
]
df_2.head()
# Out:
#     gender race/ethnicity  ... reading score writing score
# 3     male        group A  ...            57            44
# 7     male        group B  ...            43            39
# 8     male        group D  ...            64            67
# 9   female        group B  ...            60            50
# 17  female        group B  ...            32            28
#
# [5 rows x 8 columns]

# %%
sns.pairplot(df_1,hue = "gender")

# %%
sns.pairplot(df_2,hue = 'gender')

# %%
sns.pairplot(df,hue = 'lunch')

# %%
c1 = df.groupby('lunch')['lunch'].count()
sns.barplot(x = c1.index, y= c1.values)

# %%
fig, axs = plt.subplots(nrows=2)
fig.set_size_inches(5,10)
sns.swarmplot(x="lunch",y='math score',hue='gender',data = df,ax = axs[0])
sns.violinplot(x="lunch",y='math score',hue = 'gender' ,split = True,data = df,ax = axs[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 33.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
fig, axs = plt.subplots(nrows=2)
fig.set_size_inches(5,10)
sns.swarmplot(x="lunch",y='reading score',hue='gender',data = df,ax = axs[0])
sns.violinplot(x="lunch",y='reading score',hue = 'gender' ,split = True,data = df,ax = axs[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 19.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
fig, axs = plt.subplots(nrows=2)
fig.set_size_inches(5,10)
sns.swarmplot(x="lunch",y='writing score',hue='gender',data = df,ax = axs[0])
sns.violinplot(x="lunch",y='writing score',hue = 'gender' ,split = True,data = df,ax = axs[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 24.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot('gender','lunch',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## T Test to get mean of population of male and female for free/reduced and standard status

# %%
df_1 = df.copy()
df_1 = df_1[ 
            (df_1['lunch']=='standard')
]
df_1.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 4    male        group C  ...            78            75
# 5  female        group B  ...            83            78
#
# [5 rows x 8 columns]

# %%
df_2 = df.copy()
df_2 = df_2[ 
            (df_2['lunch']=='free/reduced')
]
df_2.head()
# Out:
#     gender race/ethnicity  ... reading score writing score
# 3     male        group A  ...            57            44
# 7     male        group B  ...            43            39
# 8     male        group D  ...            64            67
# 9   female        group B  ...            60            50
# 17  female        group B  ...            32            28
#
# [5 rows x 8 columns]

# %%
df_2 = df.copy()
df_2 = df_2[ 
            (df_2['lunch']=='free/reduced')
]
df_2.head()

# %%
df_2[['math score','reading score','writing score','gender']].groupby('gender').mean()
# Out:
#         math score  reading score  writing score
# gender
# female   55.814815      67.386243      66.444444
# male     62.457831      61.542169      59.126506

# %%
df_mean_2 = df_2[['math score','reading score','writing score']].mean()
print(df_mean_2)
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
df_2[['gender','parental level of education']].groupby('gender').count()
# Out:
#         parental level of education
# gender
# female                          189
# male                            166

# %%
df_1[['math score','reading score','writing score','gender']].groupby('gender').mean()
# Out:
#         math score  reading score  writing score
# gender
# female   68.124620      75.607903      75.927052
# male     72.022152      67.537975      65.509494

# %%
df_mean_1 = df_1[['math score','reading score','writing score']].mean()
print(df_mean_1)
# Out:
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
df_1[['gender','parental level of education']].groupby('gender').count()
# Out:
#         parental level of education
# gender
# female                          329
# male                            316

# %%
female_reduced_mean = (55.814815+67.386243+66.444444)/3
male_reduced_mean = (62.457831+61.542169+59.126506)/3
female_standard_mean = (68.124620+75.607903+75.927052)/3
male_standard_mean=(72.022152+67.537975+65.509494)/3
print("Female Free/Reduced mean is: ",female_reduced_mean)
print("Male Free/Reduced mean is: ",male_reduced_mean)
print("Female Standard mean is: ",female_standard_mean)
print("Male Standard mean is: ",male_standard_mean)
# Out:
# Female Free/Reduced mean is:  63.21516733333333
# Male Free/Reduced mean is:  61.04216866666667
# Female Standard mean is:  73.21985833333333
# Male Standard mean is:  68.35654033333334

# %%
df_2.head()
# Out:
#     gender race/ethnicity  ... reading score writing score
# 3     male        group A  ...            57            44
# 7     male        group B  ...            43            39
# 8     male        group D  ...            64            67
# 9   female        group B  ...            60            50
# 17  female        group B  ...            32            28
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Male free

# %%
df_2_male = df_2[
                 (df_2['gender'] == 'male')
]
df_2_male.head(2)
# Out:
#   gender race/ethnicity  ... reading score writing score
# 3   male        group A  ...            57            44
# 7   male        group B  ...            43            39
#
# [2 rows x 8 columns]

# %%
df_2_male.drop('gender',axis = 1,inplace = True)

# %%
df_2_male.drop('race/ethnicity',axis = 1,inplace = True)
df_2_male.drop('parental level of education',axis = 1,inplace = True)
df_2_male.drop('lunch',axis = 1,inplace = True)
df_2_male.drop('test preparation course',axis = 1,inplace = True)
df_2_male.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    math score  reading score  writing score
# 3          47             57             44
# 7          40             43             39

# %%
df_2_male['mean/person'] = df_2_male[['math score','reading score','writing score']].mean(axis = 1)
df_2_male.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    math score  reading score  writing score  mean/person
# 3          47             57             44    49.333333
# 7          40             43             39    40.666667

# %%
df_2_male['total/person'] = df_2_male[['math score','reading score','writing score']].sum(axis = 1)
df_2_male.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    math score  reading score  writing score  mean/person  total/person
# 3          47             57             44    49.333333           148
# 7          40             43             39    40.666667           122

# %%
import math

# %%
df_2_male['(xi-xbar)^2'] = (df_2_male['total/person'] - df_2_male['mean/person'])**2
df_2_male.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    math score  reading score  ...  total/person  (xi-xbar)^2
# 3          47             57  ...           148  9735.111111
# 7          40             43  ...           122  6615.111111
#
# [2 rows x 6 columns]

# %%
print("sum of (xi-xbar)^2/165 = ",(df_2_male['(xi-xbar)^2'].mean(axis = 0))/165)
k = (df_2_male['(xi-xbar)^2'].mean(axis = 0))/165
# Out:
# sum of (xi-xbar)^2/165 =  94.66191229564727

# %%
print("Standard deviation of free male: ",math.sqrt(k))
# Out:
# Standard deviation of free male:  9.729435353382398

# %% [markdown]
# ### Female Free

# %%
df_2_female = df_2[
                 (df_2['gender'] == 'female')
]
df_2_female.head(2)
# Out:
#     gender race/ethnicity  ... reading score writing score
# 9   female        group B  ...            60            50
# 17  female        group B  ...            32            28
#
# [2 rows x 8 columns]

# %%
df_2_female.drop('gender',axis = 1,inplace = True)
df_2_female.drop('race/ethnicity',axis = 1,inplace = True)
df_2_female.drop('parental level of education',axis = 1,inplace = True)
df_2_female.drop('lunch',axis = 1,inplace = True)
df_2_female.drop('test preparation course',axis = 1,inplace = True)
df_2_female.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     math score  reading score  writing score
# 9           38             60             50
# 17          18             32             28

# %%
df_2_female['mean/person'] = df_2_female[['math score','reading score','writing score']].mean(axis = 1)
df_2_female.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     math score  reading score  writing score  mean/person
# 9           38             60             50    49.333333
# 17          18             32             28    26.000000

# %%
df_2_female['total/person'] = df_2_female[['math score','reading score','writing score']].sum(axis = 1)
df_2_female.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     math score  reading score  writing score  mean/person  total/person
# 9           38             60             50    49.333333           148
# 17          18             32             28    26.000000            78

# %%
df_2_female['(xi-xbar)^2'] = (df_2_female['total/person'] - df_2_female['mean/person'])**2
df_2_female.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     math score  reading score  ...  total/person  (xi-xbar)^2
# 9           38             60  ...           148  9735.111111
# 17          18             32  ...            78  2704.000000
#
# [2 rows x 6 columns]

# %%
print("sum of (xi-xbar)^2/189 = ",(df_2_male['(xi-xbar)^2'].mean(axis = 0))/189)
k = (df_2_male['(xi-xbar)^2'].mean(axis = 0))/189
print("Standard deviation of free female: ",math.sqrt(k))
# Out:
# sum of (xi-xbar)^2/189 =  82.64135200413651
# Standard deviation of free female:  9.090728903896348

# %% [markdown]
# ### Results for Free/Reduced Population

# %%
alpha = 0.05
Total_male = 165
Total_female = 189
Male_mean = 61.04216866666667
Male_std = 9.729435353382398
Female_mean = 63.21516733333333
Female_std = 9.090728903896348
lower_bound_male = Male_mean - 1.6542*(Male_std/math.sqrt(Total_male))
upper_bound_male = Male_mean + 1.6542*(Male_std/math.sqrt(Total_male))
lower_bound_female = Female_mean - 1.6529*(Female_std/math.sqrt(Total_female))
upper_bound_female = Female_mean + 1.6529*(Female_std/math.sqrt(Total_female))
print("Expected Mean for males all over india under free/reduced status:",lower_bound_male,"<mean<",upper_bound_male)
print("Expected Mean for females all over india under free/reduced status:",lower_bound_female,"<mean<",upper_bound_female)
# Out:
# Expected Mean for males all over india under free/reduced status: 59.789218837770875 <mean< 62.29511849556246
# Expected Mean for females all over india under free/reduced status: 62.12218187381037 <mean< 64.3081527928563

# %% [markdown]
# ### Male Standard

# %%
df_1_male = df_1[
                 (df_1['gender'] == 'female')
]
df_1_male.head(2)
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
#
# [2 rows x 8 columns]

# %%
df_1_male.drop('gender',axis = 1,inplace = True)
df_1_male.drop('race/ethnicity',axis = 1,inplace = True)
df_1_male.drop('parental level of education',axis = 1,inplace = True)
df_1_male.drop('lunch',axis = 1,inplace = True)
df_1_male.drop('test preparation course',axis = 1,inplace = True)
df_1_male.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88

# %%
df_1_male['mean/person'] = df_1_male[['math score','reading score','writing score']].mean(axis = 1)
df_1_male.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    math score  reading score  writing score  mean/person
# 0          72             72             74    72.666667
# 1          69             90             88    82.333333

# %%
df_1_male['total/person'] = df_1_male[['math score','reading score','writing score']].sum(axis = 1)
df_1_male.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    math score  reading score  writing score  mean/person  total/person
# 0          72             72             74    72.666667           218
# 1          69             90             88    82.333333           247

# %%
df_1_male['(xi-xbar)^2'] = (df_1_male['total/person'] - df_1_male['mean/person'])**2
df_1_male.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    math score  reading score  ...  total/person   (xi-xbar)^2
# 0          72             72  ...           218  21121.777778
# 1          69             90  ...           247  27115.111111
#
# [2 rows x 6 columns]

# %%
print("sum of (xi-xbar)^2/316 = ",(df_1_male['(xi-xbar)^2'].mean(axis = 0))/316)
k = (df_1_male['(xi-xbar)^2'].mean(axis = 0))/316
print("Standard deviation of standard male: ",math.sqrt(k))
# Out:
# sum of (xi-xbar)^2/316 =  69.91660361065149
# Standard deviation of standard male:  8.361614892510387

# %% [markdown]
# ### Female Standard

# %%
df_1_female = df_1[
                 (df_1['gender'] == 'female')
]
df_1_female.head(2)
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
#
# [2 rows x 8 columns]

# %%
df_1_female.drop('gender',axis = 1,inplace = True)
df_1_female.drop('race/ethnicity',axis = 1,inplace = True)
df_1_female.drop('parental level of education',axis = 1,inplace = True)
df_1_female.drop('lunch',axis = 1,inplace = True)
df_1_female.drop('test preparation course',axis = 1,inplace = True)
df_1_female.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88

# %%
df_1_female['mean/person'] = df_1_female[['math score','reading score','writing score']].mean(axis = 1)
df_1_female.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    math score  reading score  writing score  mean/person
# 0          72             72             74    72.666667
# 1          69             90             88    82.333333

# %%
df_1_female['total/person'] = df_1_female[['math score','reading score','writing score']].sum(axis = 1)
df_1_female.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    math score  reading score  writing score  mean/person  total/person
# 0          72             72             74    72.666667           218
# 1          69             90             88    82.333333           247

# %%
df_1_female['(xi-xbar)^2'] = (df_1_female['total/person'] - df_1_female['mean/person'])**2
df_1_female.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    math score  reading score  ...  total/person   (xi-xbar)^2
# 0          72             72  ...           218  21121.777778
# 1          69             90  ...           247  27115.111111
#
# [2 rows x 6 columns]

# %%
print("sum of (xi-xbar)^2/329 = ",(df_1_female['(xi-xbar)^2'].mean(axis = 0))/329)
k = (df_1_female['(xi-xbar)^2'].mean(axis = 0))/329
print("Standard deviation of standard female: ",math.sqrt(k))
# Out:
# sum of (xi-xbar)^2/329 =  67.15394146190235
# Standard deviation of standard female:  8.194750848067459

# %% [markdown]
# ### Result for Standard Population

# %%
alpha = 0.05
Total_male = 316
Total_female = 329
Male_mean = 68.35654033333334
Male_std = 8.361614892510387
Female_mean = 73.21985833333333
Female_std = 8.194750848067459
lower_bound_male = Male_mean - 1.6497*(Male_std/math.sqrt(Total_male))
upper_bound_male = Male_mean + 1.6497*(Male_std/math.sqrt(Total_male))
lower_bound_female = Female_mean - 1.6495*(Female_std/math.sqrt(Total_female))
upper_bound_female = Female_mean + 1.6495*(Female_std/math.sqrt(Total_female))
print("Expected Mean for males all over india under standard status:",lower_bound_male,"<mean<",upper_bound_male)
print("Expected Mean for females all over india under standard status:",lower_bound_female,"<mean<",upper_bound_female)
# Out:
# Expected Mean for males all over india under free/reduced status: 67.58055842741884 <mean< 69.13252223924785
# Expected Mean for females all over india under free/reduced status: 72.47462868468452 <mean< 73.96508798198215

# %%
alpha = 0.05
Total_male = 165
Total_female = 189
Male_mean = 61.04216866666667
Male_std = 9.729435353382398
Female_mean = 63.21516733333333
Female_std = 9.090728903896348
lower_bound_male = Male_mean - 1.6542*(Male_std/math.sqrt(Total_male))
upper_bound_male = Male_mean + 1.6542*(Male_std/math.sqrt(Total_male))
lower_bound_female = Female_mean - 1.6529*(Female_std/math.sqrt(Total_female))
upper_bound_female = Female_mean + 1.6529*(Female_std/math.sqrt(Total_female))
print("Expected Mean for males all over india under free/reduced status with 95% Confidence:",lower_bound_male,"<mean<",upper_bound_male)
print("Expected Mean for females all over india under free/reduced status with 95% Confidence:",lower_bound_female,"<mean<",upper_bound_female)
# Out:
# Expected Mean for males all over india under free/reduced status with 95% Confidence: 59.789218837770875 <mean< 62.29511849556246
# Expected Mean for females all over india under free/reduced status with 95% Confidence: 62.12218187381037 <mean< 64.3081527928563

# %%
print("Expected Mean for students all over india under standard status with 95% Confidence:",(67.58055842741884+72.47462868468452)/2,"<mean<",(69.13252223924785+73.96508798198215)/2)
print("Expected Mean for students all over india under free/reduced status with 95% Confidence:",(59.789218837770875+62.12218187381037)/2,"<mean<",(62.29511849556246+64.3081527928563)/2)
# Out:
# Expected Mean for students all over india under standard status with 95% Confidence: 70.02759355605167 <mean< 71.548805110615
# Expected Mean for students all over india under free/reduced status with 95% Confidence: 60.955700355790626 <mean< 63.301635644209384
